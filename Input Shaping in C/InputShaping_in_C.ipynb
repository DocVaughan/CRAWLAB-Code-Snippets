// %% [markdown]
// <h1 style="text-align:center">Input Shaping in C</h1>
// <h3 style="text-align:center">05/23/18</h3>
// <p style="text-align:center">Dr. Joshua Vaughan <br>
// <a href="mailto:joshua.vaughan@louisiana.edu">joshua.vaughan@louisiana.edu</a><br>
// <a href="http://www.ucs.louisiana.edu/~jev9637/">http://www.ucs.louisiana.edu/~jev9637/</a></p>

// %% [markdown]
// This notebook demonstrates a *very* basic implementation of input shaping in C, using the [Minimal C kernel for Jupyter](https://github.com/brendan-rius/jupyter-c-kernel). That kernal needs to be installed following the instructions on the project GitHub page.
//
// The C kernel requires that all the C code be included in a single cell and cannot link to uncompiled code elsewhere. So, here the code to generate the shapers, the `create_Shaper()` family of functions, and implement input shaping, the `doInputShaping()` function, are included alongside the `main()` function.

// %%
#include <stdio.h>
#include <stdlib.h>
#include <math.h>

#define PI acos(-1.0)
#define HZ_TO_RADS (2.0 * PI)


#define SHAPER_BUFFER_LENGTH (601)

typedef struct { 
    int const NUM_IMPULSES;         // the number of shaper impulses
    int SAMPLE_RATE;                // sampling/loop update rate (Hz)
    int BUFFER_LENGTH;              // length of buffer to hold shaped values
    float AMPS[3];                  // shaper impulse amplitudes
    float TIMES[3];                 // shaper impulse times (s)
    int impulse_buffer_pos[3];      // index of buffer position for each imp.
    // finally, the buffer to keep track of the shaped input
    float shaped_output_buffer[SHAPER_BUFFER_LENGTH]; 
}  input_shaper;


// Functions to create input shapers to fill the struct type defined above
input_shaper createZVShaper(float nat_freq, float damping, int sample_rate);
input_shaper createZVDShaper(float nat_freq, float damping, int sample_rate);
input_shaper createEIShaper(float nat_freq, float damping, float vib_tol, int sample_rate);


// Functions to implement the shaping
float doInputShaping(float unshapedCommand, input_shaper *shaper);

/*----- Shaper Creation -----------------------------------------------------*/
input_shaper createZVShaper(float nat_freq, float damping, int sample_rate)
{
    // Function to create a struct of type input_shaper representing a ZV shaper
    // 
    // Arguments:
    //   float nat_freq : frequency (Hz) to desing the shaper for
    //   float damping : damping ratio to design the shaper for
    //   int sample_rate : sample/loop update rate of controller (Hz)
    //
    // Returns:
    //   input_shaper : a struct representing the ZV shaper
    // 
    
    float wn = nat_freq * HZ_TO_RADS;
    float K = exp(-damping * PI / sqrt(1 - damping*damping));
        
    //Set up the impulse time spacing
    float shaperdeltaT = PI / (wn * sqrt(1 - damping*damping));
    
    input_shaper ZV_shaper = {2,                // Number of impulses
                          sample_rate,          // sampling rate (Hz)
                          };


    // Assign the impulse amplitudes
    ZV_shaper.AMPS[0] = 1 / (1 + K);
    ZV_shaper.AMPS[1] = K / (1 + K);
    ZV_shaper.AMPS[2] = 0;              // A ZV shaper only has two impulses
    
    // Assign the impulse times
    ZV_shaper.TIMES[0] = 0.0;
    ZV_shaper.TIMES[1] = shaperdeltaT;
    ZV_shaper.TIMES[2] = 0.0;           // A ZV shaper only has two impulses
    
    // Create the markers for each impulse's current location in the buffer
    for (int ii = 0; ii < ZV_shaper.NUM_IMPULSES; ii++)
        {
            ZV_shaper.impulse_buffer_pos[ii] = (int) ceil((ZV_shaper.TIMES[ii] * sample_rate) - 1); 
        }

    // make the buffer length twice the length of the shaper (in number of samples)
    ZV_shaper.BUFFER_LENGTH = SHAPER_BUFFER_LENGTH; //ceil(2 * ZV_shaper.TIMES[1] * sample_rate);
    
    return ZV_shaper;
}

input_shaper createZVDShaper(float nat_freq, float damping, int sample_rate)
{
    // Function to create a struct of type input_shaper representing a ZVD shaper
    // 
    // Arguments:
    //   float freq : frequency (Hz) to desing the shaper for
    //   float damping : damping ratio to design the shaper for
    //   int sample_rate : sample/loop update rate of controller (Hz)
    //
    // Returns:
    //   input_shaper : a struct representing the ZVD shaper
    // 
    
    input_shaper ZVD_shaper = {3,               // Number of impulses
                              sample_rate       // Hz
                              };

    float wn = nat_freq * HZ_TO_RADS;
    float K = exp(-damping * PI / sqrt(1 - damping*damping));
        
    //Set up the impulse time spacing
    float shaperdeltaT = PI / (wn * sqrt(1 - damping*damping));
    
    // Assign the impulse amplitudes
    ZVD_shaper.AMPS[0] = 1 / (1 + 2 * K + K * K);
    ZVD_shaper.AMPS[1] = (2 * K) / (1 + 2 * K + K * K);
    ZVD_shaper.AMPS[2] = (K * K) / (1 + 2 * K + K * K);
    
    // Assign the impulse times
    ZVD_shaper.TIMES[0] = 0.0;
    ZVD_shaper.TIMES[1] = shaperdeltaT;
    ZVD_shaper.TIMES[2] = 2 * shaperdeltaT;
    
    // Create the markers for each impulse's current location in the buffer
    for (int ii = 0; ii < ZVD_shaper.NUM_IMPULSES; ii++)
        {
            ZVD_shaper.impulse_buffer_pos[ii] = (int) ceil((ZVD_shaper.TIMES[ii] * sample_rate - 1)); 
        }
    
    // make the buffer length twice the length of the shaper (in number of samples)
    ZVD_shaper.BUFFER_LENGTH = SHAPER_BUFFER_LENGTH;
        
    return ZVD_shaper;
}


input_shaper createEIShaper(float nat_freq, float damping, float vib_tol, int sample_rate)
{
    // Function to create a struct of type input_shaper representing a EI shaper
    // 
    // Arguments:
    //   float freq : frequency (Hz) to desing the shaper for
    //   float damping : damping ratio to design the shaper for
    //   float vib_tol : tolerable percentage vibration 0.05 = 5%
    //   int sample_rate : sample/loop update rate of controller (Hz)
    //
    // Returns:
    //   input_shaper : a struct representing the EI shaper
    // 
    
    input_shaper EI_shaper = {3,                // Number of impulses
                              sample_rate       
                              };

    float wn = nat_freq * HZ_TO_RADS;
    float wd =  wn * sqrt(1 - damping*damping);
    
    // Assign the impulse amplitudes
    // Define the shaper impulse amplitudes - based on curve fits
    EI_shaper.AMPS[0] = 0.249684 + 0.249623 * vib_tol + 0.800081 * damping + 1.23328 * vib_tol * damping + 0.495987 * damping * damping + 3.17316 * vib_tol * damping * damping;
    EI_shaper.AMPS[2] = 0.251489 + 0.21474 * vib_tol - 0.832493 * damping + 1.41498 * vib_tol * damping + 0.851806 * damping * damping - 4.90094 * vib_tol * damping * damping;
       
    // Now add the 2nd impulse, since it depends on 1 and 3
    EI_shaper.AMPS[1] = 1.0 - (EI_shaper.AMPS[0] + EI_shaper.AMPS[2]);
        
    // Assign the impulse times
    EI_shaper.TIMES[0] = 0.0;
    EI_shaper.TIMES[1] = 2.0 * PI * (0.499899 + 0.461586 * vib_tol * damping + 4.26169 * vib_tol * damping * damping + 1.75601 * vib_tol * damping*damping*damping + 8.57843 * vib_tol*vib_tol * damping - 108.644 * vib_tol * vib_tol * damping * damping + 336.989 * vib_tol * vib_tol * damping*damping*damping) / wd;
    EI_shaper.TIMES[2] = 2.0 * PI / wd;
    
    // Create the markers for each impulse's current location in the buffer
    for (int ii = 0; ii < EI_shaper.NUM_IMPULSES; ii++)
        {
            EI_shaper.impulse_buffer_pos[ii] = (int) (ceil(EI_shaper.TIMES[ii] * sample_rate - 1)); 
        }
    
    // make the buffer length twice the length of the shaper (in number of samples) + 1
    EI_shaper.BUFFER_LENGTH = SHAPER_BUFFER_LENGTH;
    
    return EI_shaper;
}

float doInputShaping(float unshapedVelocity, input_shaper *shaper)
{
    /* ------------------------------------------------------------------------
    Function that does input shaping for a single axis
    The shaper is hard-coded into the function for now, will probably be 
    better to pass it as a parameter later (func will be more reusable). 
    The function takes in an unshaped velocity reference command for the 
    current timestep and returns the shaped velocity for the current 
    timestep, while propagating the later impulses into a buffer for future
    output. 
    
    Arguments:
        * float unshaped_velocity : the unshaped velocity command at 
                                    current timeste
        * three_impulse_shaper *shaper : pointer to struct holding all the
                                       key shaper parameters
    
    Returns:
        * float shaped_velocity : the input shaped velocity at 
                                  the current timestop
        * NOTE: Also saves the future input into a buffer from the curent input 
                dependent on shaper parameters
    
    Created: 02/08/16 - Joshua Vaughan - joshua.vaughan@louisiana.edu
    
    Modified:
        * 
    -------------------------------------------------------------------------*/     
    
    // During first time the function is called, initialize the buffer positions
    if (shaper->impulse_buffer_pos[0] == -1 ) 
    {
        // Define the starting buffer locations, the impulse_buffer_pos[0] location  
        // can also be thought of as the "current" output, the impulse_buffer_pos[1] 
        // location is offset by the time of the 2nd impulse (* samples/s), etc
        // Each of these locations gets updated each time the function is called
        for (int ii = 0; ii < shaper->NUM_IMPULSES; ii++)
        {
            shaper->impulse_buffer_pos[ii] = (int) (shaper->TIMES[ii] * shaper->SAMPLE_RATE) - 1; 
        }
    }
    

    // Increment the current positions in the buffers
    for (int ii = 0; ii < shaper->NUM_IMPULSES; ii++)
    {
        shaper->impulse_buffer_pos[ii]++;
    }
    
    // For each impulse, multiple the current input by the impulse amplitude 
    // and add it to the place in the buffer corresponding to the time offset
    // of the impulse. If the desired buffer position (from the time offset)
    // is outside of the buffer, wrap to the beginning. 
    for (int ii = 0; ii < shaper->NUM_IMPULSES; ii++)
    {
        // wrap the buffer location, if necessary
        if (shaper->impulse_buffer_pos[ii] > shaper->BUFFER_LENGTH) 
        {
            shaper->impulse_buffer_pos[ii] = 0;
        }
        
        shaper->shaped_output_buffer[shaper->impulse_buffer_pos[ii]] += shaper->AMPS[ii] * unshapedVelocity;
    }
    
    // set up the current output
    float current_shaped_output = shaper->shaped_output_buffer[shaper->impulse_buffer_pos[0]];
    
    // clear the current position in the buffer, because it's been used
    shaper->shaped_output_buffer[shaper->impulse_buffer_pos[0]] = 0;
    
    return current_shaped_output;
}



int main(int argc, char *argv[]) {
    
    float command[300];
    float shaped_command[300];

    //input_shaper current_shaper = createZVShaper(1.00, 0.0, 100);
    //input_shaper current_shaper = createZVDShaper(0.33, 0.0, 100);
    input_shaper current_shaper = createEIShaper(0.5, 0.0, 0.05, 100);
                
    for (int ii = 0; ii < 300; ii++)
    {
        // Define the "unshaped" input
        command[ii] = 100;
        
        // Call the input shaping function
        shaped_command[ii] = doInputShaping(command[ii], &current_shaper);
        
        // output the current unshaped input and shaped input, for comparison
        printf("sample: %d \t unshaped = %.2f \t shaped = %.2f\n", ii, command[ii], shaped_command[ii]);
        
        // Uncomment below to watch the two locations within the ring buffer
        //printf("A1_pos = %d \t A2_pos = %d\n\n", current_shaper.impulse_buffer_pos[0], current_shaper.impulse_buffer_pos[1]);
    }
    
    printf("\n\nThe shaper parameters were:\n");
    printf("A1 = %f \t A2 = %f \t A3 = %f\n",  current_shaper.AMPS[0],
                                               current_shaper.AMPS[1], 
                                               current_shaper.AMPS[2]);
                                            
    printf("T1 = %f \t T2 = %f \t T3 = %f\n", current_shaper.TIMES[0],
                                              current_shaper.TIMES[1],
                                              current_shaper.TIMES[2]);
                                            
    return 0;
        
}
// Out:
// sample: 0 	 unshaped = 100.00 	 shaped = 26.22
// sample: 1 	 unshaped = 100.00 	 shaped = 26.22
// sample: 2 	 unshaped = 100.00 	 shaped = 26.22
// sample: 3 	 unshaped = 100.00 	 shaped = 26.22
// sample: 4 	 unshaped = 100.00 	 shaped = 26.22
// sample: 5 	 unshaped = 100.00 	 shaped = 26.22
// sample: 6 	 unshaped = 100.00 	 shaped = 26.22
// sample: 7 	 unshaped = 100.00 	 shaped = 26.22
// sample: 8 	 unshaped = 100.00 	 shaped = 26.22
// sample: 9 	 unshaped = 100.00 	 shaped = 26.22
// sample: 10 	 unshaped = 100.00 	 shaped = 26.22
// sample: 11 	 unshaped = 100.00 	 shaped = 26.22
// sample: 12 	 unshaped = 100.00 	 shaped = 26.22
// sample: 13 	 unshaped = 100.00 	 shaped = 26.22
// sample: 14 	 unshaped = 100.00 	 shaped = 26.22
// sample: 15 	 unshaped = 100.00 	 shaped = 26.22
// sample: 16 	 unshaped = 100.00 	 shaped = 26.22
// sample: 17 	 unshaped = 100.00 	 shaped = 26.22
// sample: 18 	 unshaped = 100.00 	 shaped = 26.22
// sample: 19 	 unshaped = 100.00 	 shaped = 26.22
// sample: 20 	 unshaped = 100.00 	 shaped = 26.22
// sample: 21 	 unshaped = 100.00 	 shaped = 26.22
// sample: 22 	 unshaped = 100.00 	 shaped = 26.22
// sample: 23 	 unshaped = 100.00 	 shaped = 26.22
// sample: 24 	 unshaped = 100.00 	 shaped = 26.22
// sample: 25 	 unshaped = 100.00 	 shaped = 26.22
// sample: 26 	 unshaped = 100.00 	 shaped = 26.22
// sample: 27 	 unshaped = 100.00 	 shaped = 26.22
// sample: 28 	 unshaped = 100.00 	 shaped = 26.22
// sample: 29 	 unshaped = 100.00 	 shaped = 26.22
// sample: 30 	 unshaped = 100.00 	 shaped = 26.22
// sample: 31 	 unshaped = 100.00 	 shaped = 26.22
// sample: 32 	 unshaped = 100.00 	 shaped = 26.22
// sample: 33 	 unshaped = 100.00 	 shaped = 26.22
// sample: 34 	 unshaped = 100.00 	 shaped = 26.22
// sample: 35 	 unshaped = 100.00 	 shaped = 26.22
// sample: 36 	 unshaped = 100.00 	 shaped = 26.22
// sample: 37 	 unshaped = 100.00 	 shaped = 26.22
// sample: 38 	 unshaped = 100.00 	 shaped = 26.22
// sample: 39 	 unshaped = 100.00 	 shaped = 26.22
// sample: 40 	 unshaped = 100.00 	 shaped = 26.22
// sample: 41 	 unshaped = 100.00 	 shaped = 26.22
// sample: 42 	 unshaped = 100.00 	 shaped = 26.22
// sample: 43 	 unshaped = 100.00 	 shaped = 26.22
// sample: 44 	 unshaped = 100.00 	 shaped = 26.22
// sample: 45 	 unshaped = 100.00 	 shaped = 26.22
// sample: 46 	 unshaped = 100.00 	 shaped = 26.22
// sample: 47 	 unshaped = 100.00 	 shaped = 26.22
// sample: 48 	 unshaped = 100.00 	 shaped = 26.22
// sample: 49 	 unshaped = 100.00 	 shaped = 26.22
// sample: 50 	 unshaped = 100.00 	 shaped = 26.22
// sample: 51 	 unshaped = 100.00 	 shaped = 26.22
// sample: 52 	 unshaped = 100.00 	 shaped = 26.22
// sample: 53 	 unshaped = 100.00 	 shaped = 26.22
// sample: 54 	 unshaped = 100.00 	 shaped = 26.22
// sample: 55 	 unshaped = 100.00 	 shaped = 26.22
// sample: 56 	 unshaped = 100.00 	 shaped = 26.22
// sample: 57 	 unshaped = 100.00 	 shaped = 26.22
// sample: 58 	 unshaped = 100.00 	 shaped = 26.22
// sample: 59 	 unshaped = 100.00 	 shaped = 26.22
// sample: 60 	 unshaped = 100.00 	 shaped = 26.22
// sample: 61 	 unshaped = 100.00 	 shaped = 26.22
// sample: 62 	 unshaped = 100.00 	 shaped = 26.22
// sample: 63 	 unshaped = 100.00 	 shaped = 26.22
// sample: 64 	 unshaped = 100.00 	 shaped = 26.22
// sample: 65 	 unshaped = 100.00 	 shaped = 26.22
// sample: 66 	 unshaped = 100.00 	 shaped = 26.22
// sample: 67 	 unshaped = 100.00 	 shaped = 26.22
// sample: 68 	 unshaped = 100.00 	 shaped = 26.22
// sample: 69 	 unshaped = 100.00 	 shaped = 26.22
// sample: 70 	 unshaped = 100.00 	 shaped = 26.22
// sample: 71 	 unshaped = 100.00 	 shaped = 26.22
// sample: 72 	 unshaped = 100.00 	 shaped = 26.22
// sample: 73 	 unshaped = 100.00 	 shaped = 26.22
// sample: 74 	 unshaped = 100.00 	 shaped = 26.22
// sample: 75 	 unshaped = 100.00 	 shaped = 26.22
// sample: 76 	 unshaped = 100.00 	 shaped = 26.22
// sample: 77 	 unshaped = 100.00 	 shaped = 26.22
// sample: 78 	 unshaped = 100.00 	 shaped = 26.22
// sample: 79 	 unshaped = 100.00 	 shaped = 26.22
// sample: 80 	 unshaped = 100.00 	 shaped = 26.22
// sample: 81 	 unshaped = 100.00 	 shaped = 26.22
// sample: 82 	 unshaped = 100.00 	 shaped = 26.22
// sample: 83 	 unshaped = 100.00 	 shaped = 26.22
// sample: 84 	 unshaped = 100.00 	 shaped = 26.22
// sample: 85 	 unshaped = 100.00 	 shaped = 26.22
// sample: 86 	 unshaped = 100.00 	 shaped = 26.22
// sample: 87 	 unshaped = 100.00 	 shaped = 26.22
// sample: 88 	 unshaped = 100.00 	 shaped = 26.22
// sample: 89 	 unshaped = 100.00 	 shaped = 26.22
// sample: 90 	 unshaped = 100.00 	 shaped = 26.22
// sample: 91 	 unshaped = 100.00 	 shaped = 26.22
// sample: 92 	 unshaped = 100.00 	 shaped = 26.22
// sample: 93 	 unshaped = 100.00 	 shaped = 26.22
// sample: 94 	 unshaped = 100.00 	 shaped = 26.22
// sample: 95 	 unshaped = 100.00 	 shaped = 26.22
// sample: 96 	 unshaped = 100.00 	 shaped = 26.22
// sample: 97 	 unshaped = 100.00 	 shaped = 26.22
// sample: 98 	 unshaped = 100.00 	 shaped = 26.22
// sample: 99 	 unshaped = 100.00 	 shaped = 73.78
// sample: 100 	 unshaped = 100.00 	 shaped = 73.78
// sample: 101 	 unshaped = 100.00 	 shaped = 73.78
// sample: 102 	 unshaped = 100.00 	 shaped = 73.78
// sample: 103 	 unshaped = 100.00 	 shaped = 73.78
// sample: 104 	 unshaped = 100.00 	 shaped = 73.78
// sample: 105 	 unshaped = 100.00 	 shaped = 73.78
// sample: 106 	 unshaped = 100.00 	 shaped = 73.78
// sample: 107 	 unshaped = 100.00 	 shaped = 73.78
// sample: 108 	 unshaped = 100.00 	 shaped = 73.78
// sample: 109 	 unshaped = 100.00 	 shaped = 73.78
// sample: 110 	 unshaped = 100.00 	 shaped = 73.78
// sample: 111 	 unshaped = 100.00 	 shaped = 73.78
// sample: 112 	 unshaped = 100.00 	 shaped = 73.78
// sample: 113 	 unshaped = 100.00 	 shaped = 73.78
// sample: 114 	 unshaped = 100.00 	 shaped = 73.78
// sample: 115 	 unshaped = 100.00 	 shaped = 73.78
// sample: 116 	 unshaped = 100.00 	 shaped = 73.78
// sample: 117 	 unshaped = 100.00 	 shaped = 73.78
// sample: 118 	 unshaped = 100.00 	 shaped = 73.78
// sample: 119 	 unshaped = 100.00 	 shaped = 73.78
// sample: 120 	 unshaped = 100.00 	 shaped = 73.78
// sample: 121 	 unshaped = 100.00 	 shaped = 73.78
// sample: 122 	 unshaped = 100.00 	 shaped = 73.78
// sample: 123 	 unshaped = 100.00 	 shaped = 73.78
// sample: 124 	 unshaped = 100.00 	 shaped = 73.78
// sample: 125 	 unshaped = 100.00 	 shaped = 73.78
// sample: 126 	 unshaped = 100.00 	 shaped = 73.78
// sample: 127 	 unshaped = 100.00 	 shaped = 73.78
// sample: 128 	 unshaped = 100.00 	 shaped = 73.78
// sample: 129 	 unshaped = 100.00 	 shaped = 73.78
// sample: 130 	 unshaped = 100.00 	 shaped = 73.78
// sample: 131 	 unshaped = 100.00 	 shaped = 73.78
// sample: 132 	 unshaped = 100.00 	 shaped = 73.78
// sample: 133 	 unshaped = 100.00 	 shaped = 73.78
// sample: 134 	 unshaped = 100.00 	 shaped = 73.78
// sample: 135 	 unshaped = 100.00 	 shaped = 73.78
// sample: 136 	 unshaped = 100.00 	 shaped = 73.78
// sample: 137 	 unshaped = 100.00 	 shaped = 73.78
// sample: 138 	 unshaped = 100.00 	 shaped = 73.78
// sample: 139 	 unshaped = 100.00 	 shaped = 73.78
// sample: 140 	 unshaped = 100.00 	 shaped = 73.78
// sample: 141 	 unshaped = 100.00 	 shaped = 73.78
// sample: 142 	 unshaped = 100.00 	 shaped = 73.78
// sample: 143 	 unshaped = 100.00 	 shaped = 73.78
// sample: 144 	 unshaped = 100.00 	 shaped = 73.78
// sample: 145 	 unshaped = 100.00 	 shaped = 73.78
// sample: 146 	 unshaped = 100.00 	 shaped = 73.78
// sample: 147 	 unshaped = 100.00 	 shaped = 73.78
// sample: 148 	 unshaped = 100.00 	 shaped = 73.78
// sample: 149 	 unshaped = 100.00 	 shaped = 73.78
// sample: 150 	 unshaped = 100.00 	 shaped = 73.78
// sample: 151 	 unshaped = 100.00 	 shaped = 73.78
// sample: 152 	 unshaped = 100.00 	 shaped = 73.78
// sample: 153 	 unshaped = 100.00 	 shaped = 73.78
// sample: 154 	 unshaped = 100.00 	 shaped = 73.78
// sample: 155 	 unshaped = 100.00 	 shaped = 73.78
// sample: 156 	 unshaped = 100.00 	 shaped = 73.78
// sample: 157 	 unshaped = 100.00 	 shaped = 73.78
// sample: 158 	 unshaped = 100.00 	 shaped = 73.78
// sample: 159 	 unshaped = 100.00 	 shaped = 73.78
// sample: 160 	 unshaped = 100.00 	 shaped = 73.78
// sample: 161 	 unshaped = 100.00 	 shaped = 73.78
// sample: 162 	 unshaped = 100.00 	 shaped = 73.78
// sample: 163 	 unshaped = 100.00 	 shaped = 73.78
// sample: 164 	 unshaped = 100.00 	 shaped = 73.78
// sample: 165 	 unshaped = 100.00 	 shaped = 73.78
// sample: 166 	 unshaped = 100.00 	 shaped = 73.78
// sample: 167 	 unshaped = 100.00 	 shaped = 73.78
// sample: 168 	 unshaped = 100.00 	 shaped = 73.78
// sample: 169 	 unshaped = 100.00 	 shaped = 73.78
// sample: 170 	 unshaped = 100.00 	 shaped = 73.78
// sample: 171 	 unshaped = 100.00 	 shaped = 73.78
// sample: 172 	 unshaped = 100.00 	 shaped = 73.78
// sample: 173 	 unshaped = 100.00 	 shaped = 73.78
// sample: 174 	 unshaped = 100.00 	 shaped = 73.78
// sample: 175 	 unshaped = 100.00 	 shaped = 73.78
// sample: 176 	 unshaped = 100.00 	 shaped = 73.78
// sample: 177 	 unshaped = 100.00 	 shaped = 73.78
// sample: 178 	 unshaped = 100.00 	 shaped = 73.78
// sample: 179 	 unshaped = 100.00 	 shaped = 73.78
// sample: 180 	 unshaped = 100.00 	 shaped = 73.78
// sample: 181 	 unshaped = 100.00 	 shaped = 73.78
// sample: 182 	 unshaped = 100.00 	 shaped = 73.78
// sample: 183 	 unshaped = 100.00 	 shaped = 73.78
// sample: 184 	 unshaped = 100.00 	 shaped = 73.78
// sample: 185 	 unshaped = 100.00 	 shaped = 73.78
// sample: 186 	 unshaped = 100.00 	 shaped = 73.78
// sample: 187 	 unshaped = 100.00 	 shaped = 73.78
// sample: 188 	 unshaped = 100.00 	 shaped = 73.78
// sample: 189 	 unshaped = 100.00 	 shaped = 73.78
// sample: 190 	 unshaped = 100.00 	 shaped = 73.78
// sample: 191 	 unshaped = 100.00 	 shaped = 73.78
// sample: 192 	 unshaped = 100.00 	 shaped = 73.78
// sample: 193 	 unshaped = 100.00 	 shaped = 73.78
// sample: 194 	 unshaped = 100.00 	 shaped = 73.78
// sample: 195 	 unshaped = 100.00 	 shaped = 73.78
// sample: 196 	 unshaped = 100.00 	 shaped = 73.78
// sample: 197 	 unshaped = 100.00 	 shaped = 73.78
// sample: 198 	 unshaped = 100.00 	 shaped = 73.78
// sample: 199 	 unshaped = 100.00 	 shaped = 73.78
// sample: 200 	 unshaped = 100.00 	 shaped = 100.00
// sample: 201 	 unshaped = 100.00 	 shaped = 100.00
// sample: 202 	 unshaped = 100.00 	 shaped = 100.00
// sample: 203 	 unshaped = 100.00 	 shaped = 100.00
// sample: 204 	 unshaped = 100.00 	 shaped = 100.00
// sample: 205 	 unshaped = 100.00 	 shaped = 100.00
// sample: 206 	 unshaped = 100.00 	 shaped = 100.00
// sample: 207 	 unshaped = 100.00 	 shaped = 100.00
// sample: 208 	 unshaped = 100.00 	 shaped = 100.00
// sample: 209 	 unshaped = 100.00 	 shaped = 100.00
// sample: 210 	 unshaped = 100.00 	 shaped = 100.00
// sample: 211 	 unshaped = 100.00 	 shaped = 100.00
// sample: 212 	 unshaped = 100.00 	 shaped = 100.00
// sample: 213 	 unshaped = 100.00 	 shaped = 100.00
// sample: 214 	 unshaped = 100.00 	 shaped = 100.00
// sample: 215 	 unshaped = 100.00 	 shaped = 100.00
// sample: 216 	 unshaped = 100.00 	 shaped = 100.00
// sample: 217 	 unshaped = 100.00 	 shaped = 100.00
// sample: 218 	 unshaped = 100.00 	 shaped = 100.00
// sample: 219 	 unshaped = 100.00 	 shaped = 100.00
// sample: 220 	 unshaped = 100.00 	 shaped = 100.00
// sample: 221 	 unshaped = 100.00 	 shaped = 100.00
// sample: 222 	 unshaped = 100.00 	 shaped = 100.00
// sample: 223 	 unshaped = 100.00 	 shaped = 100.00
// sample: 224 	 unshaped = 100.00 	 shaped = 100.00
// sample: 225 	 unshaped = 100.00 	 shaped = 100.00
// sample: 226 	 unshaped = 100.00 	 shaped = 100.00
// sample: 227 	 unshaped = 100.00 	 shaped = 100.00
// sample: 228 	 unshaped = 100.00 	 shaped = 100.00
// sample: 229 	 unshaped = 100.00 	 shaped = 100.00
// sample: 230 	 unshaped = 100.00 	 shaped = 100.00
// sample: 231 	 unshaped = 100.00 	 shaped = 100.00
// sample: 232 	 unshaped = 100.00 	 shaped = 100.00
// sample: 233 	 unshaped = 100.00 	 shaped = 100.00
// sample: 234 	 unshaped = 100.00 	 shaped = 100.00
// sample: 235 	 unshaped = 100.00 	 shaped = 100.00
// sample: 236 	 unshaped = 100.00 	 shaped = 100.00
// sample: 237 	 unshaped = 100.00 	 shaped = 100.00
// sample: 238 	 unshaped = 100.00 	 shaped = 100.00
// sample: 239 	 unshaped = 100.00 	 shaped = 100.00
// sample: 240 	 unshaped = 100.00 	 shaped = 100.00
// sample: 241 	 unshaped = 100.00 	 shaped = 100.00
// sample: 242 	 unshaped = 100.00 	 shaped = 100.00
// sample: 243 	 unshaped = 100.00 	 shaped = 100.00
// sample: 244 	 unshaped = 100.00 	 shaped = 100.00
// sample: 245 	 unshaped = 100.00 	 shaped = 100.00
// sample: 246 	 unshaped = 100.00 	 shaped = 100.00
// sample: 247 	 unshaped = 100.00 	 shaped = 100.00
// sample: 248 	 unshaped = 100.00 	 shaped = 100.00
// sample: 249 	 unshaped = 100.00 	 shaped = 100.00
// sample: 250 	 unshaped = 100.00 	 shaped = 100.00
// sample: 251 	 unshaped = 100.00 	 shaped = 100.00
// sample: 252 	 unshaped = 100.00 	 shaped = 100.00
// sample: 253 	 unshaped = 100.00 	 shaped = 100.00
// sample: 254 	 unshaped = 100.00 	 shaped = 100.00
// sample: 255 	 unshaped = 100.00 	 shaped = 100.00
// sample: 256 	 unshaped = 100.00 	 shaped = 100.00
// sample: 257 	 unshaped = 100.00 	 shaped = 100.00
// sample: 258 	 unshaped = 100.00 	 shaped = 100.00
// sample: 259 	 unshaped = 100.00 	 shaped = 100.00
// sample: 260 	 unshaped = 100.00 	 shaped = 100.00
// sample: 261 	 unshaped = 100.00 	 shaped = 100.00
// sample: 262 	 unshaped = 100.00 	 shaped = 100.00
// sample: 263 	 unshaped = 100.00 	 shaped = 100.00
// sample: 264 	 unshaped = 100.00 	 shaped = 100.00
// sample: 265 	 unshaped = 100.00 	 shaped = 100.00
// sample: 266 	 unshaped = 100.00 	 shaped = 100.00
// sample: 267 	 unshaped = 100.00 	 shaped = 100.00
// sample: 268 	 unshaped = 100.00 	 shaped = 100.00
// sample: 269 	 unshaped = 100.00 	 shaped = 100.00
// sample: 270 	 unshaped = 100.00 	 shaped = 100.00
// sample: 271 	 unshaped = 100.00 	 shaped = 100.00
// sample: 272 	 unshaped = 100.00 	 shaped = 100.00
// sample: 273 	 unshaped = 100.00 	 shaped = 100.00
// sample: 274 	 unshaped = 100.00 	 shaped = 100.00
// sample: 275 	 unshaped = 100.00 	 shaped = 100.00
// sample: 276 	 unshaped = 100.00 	 shaped = 100.00
// sample: 277 	 unshaped = 100.00 	 shaped = 100.00
// sample: 278 	 unshaped = 100.00 	 shaped = 100.00
// sample: 279 	 unshaped = 100.00 	 shaped = 100.00
// sample: 280 	 unshaped = 100.00 	 shaped = 100.00
// sample: 281 	 unshaped = 100.00 	 shaped = 100.00
// sample: 282 	 unshaped = 100.00 	 shaped = 100.00
// sample: 283 	 unshaped = 100.00 	 shaped = 100.00
// sample: 284 	 unshaped = 100.00 	 shaped = 100.00
// sample: 285 	 unshaped = 100.00 	 shaped = 100.00
// sample: 286 	 unshaped = 100.00 	 shaped = 100.00
// sample: 287 	 unshaped = 100.00 	 shaped = 100.00
// sample: 288 	 unshaped = 100.00 	 shaped = 100.00
// sample: 289 	 unshaped = 100.00 	 shaped = 100.00
// sample: 290 	 unshaped = 100.00 	 shaped = 100.00
// sample: 291 	 unshaped = 100.00 	 shaped = 100.00
// sample: 292 	 unshaped = 100.00 	 shaped = 100.00
// sample: 293 	 unshaped = 100.00 	 shaped = 100.00
// sample: 294 	 unshaped = 100.00 	 shaped = 100.00
// sample: 295 	 unshaped = 100.00 	 shaped = 100.00
// sample: 296 	 unshaped = 100.00 	 shaped = 100.00
// sample: 297 	 unshaped = 100.00 	 shaped = 100.00
// sample: 298 	 unshaped = 100.00 	 shaped = 100.00
// sample: 299 	 unshaped = 100.00 	 shaped = 100.00
//
//
// The shaper parameters were:
// A1 = 0.262165 	 A2 = 0.475609 	 A3 = 0.262226
// T1 = 0.000000 	 T2 = 0.999798 	 T3 = 2.000000

// %% [markdown]
// <hr style="border: 0px;
//         height: 1px;
//         text-align: center;
//         background: #333;
//         background-image: -webkit-linear-gradient(left, #ccc, #333, #ccc);
//         background-image:    -moz-linear-gradient(left, #ccc, #333, #ccc);
//         background-image:     -ms-linear-gradient(left, #ccc, #333, #ccc);
//         background-image:      -o-linear-gradient(left, #ccc, #333, #ccc);">

// %% [markdown]
// #### Licenses
// Code is licensed under a 3-clause BSD style license. See the licenses/LICENSE.md file.
//
// Other content is provided under a [Creative Commons Attribution-NonCommercial 4.0 International License](http://creativecommons.org/licenses/by-nc/4.0/), CC-BY-NC 4.0.
